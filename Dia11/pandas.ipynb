# %% [markdown]
# # Pandas

# %% [markdown]
# ## Links de interes

# %% [markdown]
# - [Documentacion](https://pandas.pydata.org/docs/)
# - [W3school](https://www.w3schools.com/python/pandas/default.asp)
# - [Pandas Cheat Sheet](https://dataanalytics.buffalostate.edu/sites/dataanalytics.buffalostate.edu/files/uploads/Student%20resources/pandas_cheatsheet.jpg)

# %% [markdown]
# ## Instalación

# %% [markdown]
# ```
# pip install pandas
# ```

# %% [markdown]
# ## Importar libreria

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# ## DataFrames de Pandas

# %% [markdown]
# Un **DataFrame** es la estructura de datos con la que Pandas **almacena y manipula datos tabulados**. Es como una hoja de cálculo de Excel, tiene filas y columnas, acepta distintos tipos de datos y permite interactuar entre ellos. La diferencia con una hoja de cálculo es que es extremadamente más rápida y potente, por lo que podrás trabajar con **cantidades muy grandes de datos**.

# %% [markdown]
# En Pandas tambien tendremos otra estructura conocida como **Serie**, es como un *DataFrame de una sola dimensión*.

# %% [markdown]
# ### Creacion de DataFrames

# %% [markdown]
# Para crear DataFrames utilizaremos el metodo de Pandas **.DataFrame()**.

# %% [markdown]
# #### Con Diccionario de listas (columna por columna)

# %%
futbol_diccionario = {
    "Jugador": ["Lionel Messi", "Cristiano Ronaldo"],
    "Año": [2016, 2016],
    "Goles": [37, 25],
}
futbol_estadisticas = pd.DataFrame(futbol_diccionario)

futbol_estadisticas
# Out:
#              Jugador   Año  Goles
# 0       Lionel Messi  2016     37
# 1  Cristiano Ronaldo  2016     25

# %% [markdown]
# Las listas podrían ser **arreglos de NumPy**.

# %%
jugadores = np.array(["Lionel Messi", "Cristiano Ronaldo"])
anios = np.array([2016, 2016])
goles = np.array([37, 25])

futbol_diccionario_2 = {
    "Jugador": jugadores,
    "Año": anios,
    "Goles": goles,
}
futbol_estadisticas_2 = pd.DataFrame(futbol_diccionario)

futbol_estadisticas_2
# Out:
#              Jugador   Año  Goles
# 0       Lionel Messi  2016     37
# 1  Cristiano Ronaldo  2016     25

# %% [markdown]
# #### Con Lista de diccionarios (fila por fila)

# %%
futbol_lista = [
    {"jugador": "Lionel Messi", "año": 2016, "goles": 37},
    {"jugador": "Cristiano Ronaldo", "año": 2016, "goles": 25},
]
futbol_estadisticas = pd.DataFrame(futbol_lista)

futbol_estadisticas
# Out:
#              jugador   año  goles
# 0       Lionel Messi  2016     37
# 1  Cristiano Ronaldo  2016     25

# %% [markdown]
# ### Importar datos

# %% [markdown]
# Sería muy ineficiente ir llenando todos los datos como se indico anteriormente. Por ello, comúnmente se importan los datos de archivos CSV, JSON, entre otros.
#
# Para ello pandas tiene varias formas de **leer un archivo**, el código base suele ser:

# %% [markdown]
# ```python
# pd.read_{tipo_de_archivo}('path')
# ```

# %% [markdown]
# #### Importar .csv

# %% [markdown]
# Para cargar un **CSV (Comma Separated Values)**, sería:

# %% [markdown]
# ```python
# pd.read_csv('ruta/archivo.csv')
# ```

# %% [markdown]
# Esto **convertirá el contenido del CSV en un DataFrame**, el cual por convención se nombra como **df**.

# %%
df = pd.read_csv('futbol_mini_estadisticas.csv')

df
# Out:
#              jugador   año  goles
# 0       Lionel Messi  2016     37
# 1  Cristiano Ronaldo  2016     25

# %% [markdown]
# ### Indices DataFrame

# %% [markdown]
# A la izquierda *por defecto apareceran los indices desde la posicion 0* al inicio de cada fila.
#
# Sin embargo, no ajuro tendria que ser de esta manera. Se puede indicar el indice que deseamos para nuestro DataFrame con el argumento:

# %% [markdown]
# ```python
# index_col='nombre_columna'
# ```

# %%
df = pd.read_csv('futbol_mini_estadisticas.csv', index_col='jugador')

df
# Out:
#                     año  goles
# jugador
# Lionel Messi       2016     37
# Cristiano Ronaldo  2016     25

# %% [markdown]
# ### Inspeccion de DataFrames

# %% [markdown]
# Antes de empezar a realizar un análisis de datos es muy importante que primero se inspeccione el DataFrame a estudiar:
#
# - Pequeña muestra de los datos.
# - ¿Cuántas filas hay?
# - ¿Qué columnas existen?
# - ¿Qué tipos de datos hay?
# - ¿Faltan datos?
# - Ligera vista de estadísticas descriptivas.

# %% [markdown]
# Para esta inspeccion usaremos **futbol_estadisticas.csv**, colocando como indice la columna **player_id**:

# %%
df = pd.read_csv('futbol_estadisticas.csv', index_col='jugador_id')

df
# Out:
#                  nombre_jugador   año  juegos  goles  goles_sin_penalti  \
# jugador_id
# 8865              Ollie Watkins  2020       9      6                  5
# 675               Jack Grealish  2020       9      5                  5
# 592                Ross Barkley  2020       6      2                  2
# 1024               Tyrone Mings  2020       9      2                  2
# 7726           Ezri Konsa Ngoyo  2020       9      2                  2
# ...                         ...   ...     ...    ...                ...
# 4267           Florian Hartherz  2014      10      0                  0
# 4268        Christian Strohdiek  2014      22      0                  0
# 4311                 Idir Ouali  2014       6      0                  0
# 4334               Mirnes Pepic  2014       2      0                  0
# 4363             Thomas Bertels  2014       1      0                  0
#
#             tiros  asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 8865           22            1                   0               0        F
# 675            26            5                   2               0      F M
# 592            17            1                   0               0        M
# 1024            7            1                   2               0        D
# 7726            7            0                   0               0        D
# ...           ...          ...                 ...             ...      ...
# 4267            1            2                   1               1      D S
# 4268            6            0                   2               0      D S
# 4311            4            0                   1               0      M S
# 4334            0            0                   0               0        S
# 4363            0            0                   0               0        S
#
#            nombre_equipo  tiempo
# jugador_id
# 8865         Aston Villa     810
# 675          Aston Villa     810
# 592          Aston Villa     454
# 1024         Aston Villa     810
# 7726         Aston Villa     810
# ...                  ...     ...
# 4267           Paderborn     775
# 4268           Paderborn    1608
# 4311           Paderborn     296
# 4334           Paderborn      20
# 4363           Paderborn       3
#
# [18633 rows x 12 columns]

# %% [markdown]
# **Descripcion**
#
# - **jugador_id** → ID único que ayuda a identificar a cada jugador.
# - **nombre_jugador** → El nombre del jugador.
# - **año** → Temporada en la que se recogieron los datos.
# - **juegos** → Número de juegos en los que ha participado el jugador en esa temporada.
# - **goles** → Goles marcados en esa temporada.
# - **npg** → Goles sin penalti marcados en esa temporada.
# - **tiros** → Tiros en esa temporada.
# - **asistencias** → Asistencias de la temporada.
# - **tarjetas_amarillas** → Tarjetas amarillas recibidas en esa temporada.
# - **red_cards** → Tarjetas rojas recibidas en esa temporada.
# - **posicion** → Posición jugada a lo largo de la temporada.
#   - F → Delantero
#   - M → Mediocampo
#   - D → Defensa
#   - GK → Portero.
# - **nombre_equipo** → El equipo en el que jugó el jugador en esa temporada, si el jugador cambió de club a mitad de temporada, ese jugador tendrá dos entradas para esa temporada específica.
# - **tiempo** → Número de minutos que ha jugado el jugador en esa temporada.

# %% [markdown]
# #### Obtener primeras filas con **.head()**

# %% [markdown]
# Retorna las 5 primeras filas.

# %%
df.head()
# Out:
#               nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 8865           Ollie Watkins  2020       9      6                  5     22
# 675            Jack Grealish  2020       9      5                  5     26
# 592             Ross Barkley  2020       6      2                  2     17
# 1024            Tyrone Mings  2020       9      2                  2      7
# 7726        Ezri Konsa Ngoyo  2020       9      2                  2      7
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 8865                  1                   0               0        F
# 675                   5                   2               0      F M
# 592                   1                   0               0        M
# 1024                  1                   2               0        D
# 7726                  0                   0               0        D
#
#            nombre_equipo  tiempo
# jugador_id
# 8865         Aston Villa     810
# 675          Aston Villa     810
# 592          Aston Villa     454
# 1024         Aston Villa     810
# 7726         Aston Villa     810

# %% [markdown]
# También se le puede pasar un entero como parámetro y devolverá esa cantidad de primeras filas.

# %%
df.head(8)
# Out:
#               nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 8865           Ollie Watkins  2020       9      6                  5     22
# 675            Jack Grealish  2020       9      5                  5     26
# 592             Ross Barkley  2020       6      2                  2     17
# 1024            Tyrone Mings  2020       9      2                  2      7
# 7726        Ezri Konsa Ngoyo  2020       9      2                  2      7
# 7721         Conor Hourihane  2020       4      1                  1      5
# 7723             John McGinn  2020       9      1                  1     10
# 695          Bertrand Traoré  2020       7      0                  0      5
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 8865                  1                   0               0        F
# 675                   5                   2               0      F M
# 592                   1                   0               0        M
# 1024                  1                   2               0        D
# 7726                  0                   0               0        D
# 7721                  1                   0               0      M S
# 7723                  4                   3               0        M
# 695                   1                   0               0      M S
#
#            nombre_equipo  tiempo
# jugador_id
# 8865         Aston Villa     810
# 675          Aston Villa     810
# 592          Aston Villa     454
# 1024         Aston Villa     810
# 7726         Aston Villa     810
# 7721         Aston Villa     236
# 7723         Aston Villa     810
# 695          Aston Villa     147

# %% [markdown]
# #### Obtener ultimas filas con **.tail()**

# %% [markdown]
# Retorna las últimas 5 filas.

# %%
df.tail()
# Out:
#                  nombre_jugador   año  juegos  goles  goles_sin_penalti  \
# jugador_id
# 4267           Florian Hartherz  2014      10      0                  0
# 4268        Christian Strohdiek  2014      22      0                  0
# 4311                 Idir Ouali  2014       6      0                  0
# 4334               Mirnes Pepic  2014       2      0                  0
# 4363             Thomas Bertels  2014       1      0                  0
#
#             tiros  asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 4267            1            2                   1               1      D S
# 4268            6            0                   2               0      D S
# 4311            4            0                   1               0      M S
# 4334            0            0                   0               0        S
# 4363            0            0                   0               0        S
#
#            nombre_equipo  tiempo
# jugador_id
# 4267           Paderborn     775
# 4268           Paderborn    1608
# 4311           Paderborn     296
# 4334           Paderborn      20
# 4363           Paderborn       3

# %% [markdown]
# También se le puede pasar un entero como parámetro y devolverá esa cantidad de ultimas filas.

# %%
df.tail(8)
# Out:
#                  nombre_jugador   año  juegos  goles  goles_sin_penalti  \
# jugador_id
# 4257           Michael Heinloth  2014      21      0                  0
# 4259            Daniel Brückner  2014      23      0                  0
# 4260            Patrick Ziegler  2014      27      0                  0
# 4267           Florian Hartherz  2014      10      0                  0
# 4268        Christian Strohdiek  2014      22      0                  0
# 4311                 Idir Ouali  2014       6      0                  0
# 4334               Mirnes Pepic  2014       2      0                  0
# 4363             Thomas Bertels  2014       1      0                  0
#
#             tiros  asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 4257            6            1                   2               1      D S
# 4259            8            1                   5               0        D
# 4260           11            0                   7               0    D M S
# 4267            1            2                   1               1      D S
# 4268            6            0                   2               0      D S
# 4311            4            0                   1               0      M S
# 4334            0            0                   0               0        S
# 4363            0            0                   0               0        S
#
#            nombre_equipo  tiempo
# jugador_id
# 4257           Paderborn    1641
# 4259           Paderborn    2024
# 4260           Paderborn    1948
# 4267           Paderborn     775
# 4268           Paderborn    1608
# 4311           Paderborn     296
# 4334           Paderborn      20
# 4363           Paderborn       3

# %% [markdown]
# #### Obtener muestras al azar con **.sample()**

# %% [markdown]
# Retorna muestras al azar del DataFrame, es obligatorio especificar la **cantidad**.

# %%
df.sample(5)
# Out:
#                nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 751         N&#039;Golo Kanté  2020      11      0                  0      2
# 2120            Gerard Moreno  2015      32      7                  6     51
# 1507                  Miranda  2017      31      0                  0      9
# 1821        Christian Abbiati  2015       1      0                  0      0
# 2357            Nabil El Zhar  2014      17      1                  1     10
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 751                   1                   1               0        M
# 2120                  3                   3               1    F M S
# 1507                  0                   8               0        D
# 1821                  0                   0               0        S
# 2357                  2                   3               0      M S
#
#            nombre_equipo  tiempo
# jugador_id
# 751              Chelsea     984
# 2120            Espanyol    1914
# 1507               Inter    2732
# 1821            AC Milan      72
# 2357             Levante     665

# %% [markdown]
# #### Obtener cantidad de filas y columnas con **.shape**

# %% [markdown]
# Retorna la cantidad de filas y columnas que tiene el DataFrame.

# %%
df.shape
# Out:
# (18633, 12)

# %% [markdown]
# #### Obtener cantidad de elementos con **.size**

# %% [markdown]
# Multiplica las filas y columnas y da el total de datos del DataFrame.

# %%
df.size
# Out:
# 223596

# %% [markdown]
# #### Obtener informacion del DataFrame con **.info()**

# %% [markdown]
# Indica:
# - Cantidad de valores no nulos.
# - El tipo de dato de cada columna.
# - El uso de memoria.

# %% [markdown]
# **ADVERTENCIA**
#
# Solo debemos tener un tipo de dato en cada columna del DataDrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18633 entries, 8865 to 4363
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nombre_jugador      18633 non-null  object
#  1   año                 18633 non-null  int64
#  2   juegos              18633 non-null  int64
#  3   goles               18633 non-null  int64
#  4   goles_sin_penalti   18633 non-null  int64
#  5   tiros               18633 non-null  int64
#  6   asistencias         18633 non-null  int64
#  7   tarjetas_amarillas  18633 non-null  int64
#  8   tarjetas_rojas      18633 non-null  int64
#  9   posicion            18633 non-null  object
#  10  nombre_equipo       18633 non-null  object
#  11  tiempo              18633 non-null  int64
# dtypes: int64(9), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# #### Obtener estadisticas descriptivas con **.describe()**

# %% [markdown]
# Ayuda mucho con las primeras impresiones de los datos, ya que calcula algunas estadísticas descriptivas para cada columna.

# %%
df.describe()
# Out:
#                 año        juegos         goles  goles_sin_penalti  \
# count  18633.000000  18633.000000  18633.000000       18633.000000
# mean    2016.937691     17.072291      1.624054           1.478399
# std        1.976606     11.375527      3.252418           2.891849
# min     2014.000000      1.000000      0.000000           0.000000
# 25%     2015.000000      7.000000      0.000000           0.000000
# 50%     2017.000000     16.000000      0.000000           0.000000
# 75%     2019.000000     27.000000      2.000000           2.000000
# max     2020.000000     38.000000     48.000000          38.000000
#
#               tiros   asistencias  tarjetas_amarillas  tarjetas_rojas  \
# count  18633.000000  18633.000000        18633.000000    18633.000000
# mean      15.323888      1.138088            2.453979        0.127569
# std       20.934645      1.936238            2.685745        0.370656
# min        0.000000      0.000000            0.000000        0.000000
# 25%        1.000000      0.000000            0.000000        0.000000
# 50%        8.000000      0.000000            2.000000        0.000000
# 75%       21.000000      2.000000            4.000000        0.000000
# max      227.000000     20.000000           17.000000        5.000000
#
#              tiempo
# count  18633.000000
# mean    1207.483282
# std      975.753086
# min        1.000000
# 25%      326.000000
# 50%      976.000000
# 75%     2004.000000
# max     3420.000000

# %% [markdown]
# El **método describe()** devuelve información estadística de los datos del DataFrame o de la Serie, en forma de DataFrame.
#
# Esta información incluye:
#
# - Número de muestras no nulas (count)
# - El valor promedio (mean)
# - Desviación estándar(std)
# - Valor mínimo (min)
# - El percentil 25%
# - El percentil 50%
# - El percentil 75%
# - Valor máximo (max)

# %% [markdown]
# *Percentil: Cuántos de los valores son menores que el percentil dado.*

# %% [markdown]
# ### Ordenamiento de datos

# %% [markdown]
# Pandas nos permite ordenar columnas de un DataFrame:

# %% [markdown]
# ```python
# df.sort_values()
# ```

# %% [markdown]
# Este metodo recibe 2 parámetros:
#
# - **by:** Recibe el nombre de la columna que se queire ordenar, o una lista de columnas a ordenar.
# - **ascending:** Recibe un booleano que indica si se quiere ordenar ascendentemente o no, o una lista de booleanos.

# %%
df.sort_values('nombre_jugador', ascending = True)
# Out:
#              nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 7991         Aaron Connolly  2020       8      1                  1      9
# 7991         Aaron Connolly  2019      24      3                  3     36
# 534         Aaron Cresswell  2014      38      2                  2     19
# 534         Aaron Cresswell  2017      36      1                  1     21
# 534         Aaron Cresswell  2015      37      2                  2     28
# ...                     ...   ...     ...    ...                ...    ...
# 2646         Özkan Yildirim  2014       1      0                  0      0
# 2646         Özkan Yildirim  2015       1      0                  0      1
# 250            Ørjan Nyland  2016      12      0                  0      0
# 250            Ørjan Nyland  2015       6      0                  0      0
# 250            Ørjan Nyland  2019       7      0                  0      0
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 7991                  1                   0               0      F S
# 7991                  1                   0               0      F S
# 534                   4                   5               0        D
# 534                   7                   7               0      D S
# 534                   4                   1               0      D M
# ...                 ...                 ...             ...      ...
# 2646                  0                   0               0        M
# 2646                  0                   0               0        S
# 250                   0                   0               0     GK S
# 250                   0                   0               0       GK
# 250                   0                   0               0     GK S
#
#             nombre_equipo  tiempo
# jugador_id
# 7991             Brighton     425
# 7991             Brighton    1279
# 534              West Ham    3420
# 534              West Ham    3081
# 534              West Ham    3319
# ...                   ...     ...
# 2646        Werder Bremen      60
# 2646        Werder Bremen      13
# 250            Ingolstadt    1021
# 250            Ingolstadt     540
# 250           Aston Villa     536
#
# [18633 rows x 12 columns]

# %%
df.sort_values('nombre_jugador', ascending = False)
# Out:
#              nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 250            Ørjan Nyland  2015       6      0                  0      0
# 250            Ørjan Nyland  2016      12      0                  0      0
# 250            Ørjan Nyland  2019       7      0                  0      0
# 2646         Özkan Yildirim  2014       1      0                  0      0
# 2646         Özkan Yildirim  2015       1      0                  0      1
# ...                     ...   ...     ...    ...                ...    ...
# 534         Aaron Cresswell  2018      20      0                  0     11
# 534         Aaron Cresswell  2020      11      0                  0      4
# 534         Aaron Cresswell  2019      31      3                  3     18
# 7991         Aaron Connolly  2019      24      3                  3     36
# 7991         Aaron Connolly  2020       8      1                  1      9
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 250                   0                   0               0       GK
# 250                   0                   0               0     GK S
# 250                   0                   0               0     GK S
# 2646                  0                   0               0        M
# 2646                  0                   0               0        S
# ...                 ...                 ...             ...      ...
# 534                   1                   1               0      D S
# 534                   3                   0               0        D
# 534                   0                   7               0        D
# 7991                  1                   0               0      F S
# 7991                  1                   0               0      F S
#
#             nombre_equipo  tiempo
# jugador_id
# 250            Ingolstadt     540
# 250            Ingolstadt    1021
# 250           Aston Villa     536
# 2646        Werder Bremen      60
# 2646        Werder Bremen      13
# ...                   ...     ...
# 534              West Ham    1586
# 534              West Ham     990
# 534              West Ham    2739
# 7991             Brighton    1279
# 7991             Brighton     425
#
# [18633 rows x 12 columns]

# %% [markdown]
# **Nota**
#
# En la mayoría de funciones de pandas se puede pasar más de un valor mediante el uso de **listas**.

# %%
df.sort_values(['jugador_id', 'año'], ascending=[True, False])
# Out:
#                 nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 1           Christian Mathenia  2018      22      0                  0      0
# 1           Christian Mathenia  2017      24      0                  0      0
# 1           Christian Mathenia  2016      14      0                  0      0
# 1           Christian Mathenia  2015      33      0                  0      0
# 2                György Garics  2015      21      0                  0      3
# ...                        ...   ...     ...    ...                ...    ...
# 9161          Jan-Luca Schuler  2020       1      0                  0      1
# 9163                Kean Bryan  2020       2      0                  0      0
# 9170                 John Finn  2020       1      0                  0      0
# 9174            Edgar Sevikyan  2020       1      0                  0      0
# 9177          Giuseppe Mastinu  2020       1      0                  0      0
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 1                     0                   2               0       GK
# 1                     0                   2               0       GK
# 1                     0                   1               0       GK
# 1                     0                   3               0       GK
# 2                     0                   8               0      D S
# ...                 ...                 ...             ...      ...
# 9161                  0                   0               0        S
# 9163                  0                   0               0        D
# 9170                  0                   0               0        S
# 9174                  0                   0               0        S
# 9177                  0                   0               0        S
#
#                nombre_equipo  tiempo
# jugador_id
# 1                  Nuernberg    1933
# 1               Hamburger SV    2160
# 1               Hamburger SV    1260
# 1                  Darmstadt    2970
# 2                  Darmstadt    1796
# ...                      ...     ...
# 9161              Schalke 04       8
# 9163        Sheffield United     155
# 9170                  Getafe       4
# 9174                 Levante       5
# 9177                  Spezia       1
#
# [18633 rows x 12 columns]

# %%
df.sort_values(['jugador_id', 'año'], ascending=[True, True])
# Out:
#                 nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 1           Christian Mathenia  2015      33      0                  0      0
# 1           Christian Mathenia  2016      14      0                  0      0
# 1           Christian Mathenia  2017      24      0                  0      0
# 1           Christian Mathenia  2018      22      0                  0      0
# 2                György Garics  2015      21      0                  0      3
# ...                        ...   ...     ...    ...                ...    ...
# 9161          Jan-Luca Schuler  2020       1      0                  0      1
# 9163                Kean Bryan  2020       2      0                  0      0
# 9170                 John Finn  2020       1      0                  0      0
# 9174            Edgar Sevikyan  2020       1      0                  0      0
# 9177          Giuseppe Mastinu  2020       1      0                  0      0
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 1                     0                   3               0       GK
# 1                     0                   1               0       GK
# 1                     0                   2               0       GK
# 1                     0                   2               0       GK
# 2                     0                   8               0      D S
# ...                 ...                 ...             ...      ...
# 9161                  0                   0               0        S
# 9163                  0                   0               0        D
# 9170                  0                   0               0        S
# 9174                  0                   0               0        S
# 9177                  0                   0               0        S
#
#                nombre_equipo  tiempo
# jugador_id
# 1                  Darmstadt    2970
# 1               Hamburger SV    1260
# 1               Hamburger SV    2160
# 1                  Nuernberg    1933
# 2                  Darmstadt    1796
# ...                      ...     ...
# 9161              Schalke 04       8
# 9163        Sheffield United     155
# 9170                  Getafe       4
# 9174                 Levante       5
# 9177                  Spezia       1
#
# [18633 rows x 12 columns]

# %% [markdown]
# ### Filtrado de datos y Subconjuntos

# %% [markdown]
# No ajuro vamos a necesitar todo el DataFrame para realizar un análisis de los datos, muchas veces será más cómodo solo tener una parte de este.
#
# Es por esto, que podemos crear **subconjuntos**.

# %% [markdown]
# #### Seleccionar una columna

# %%
df["nombre_jugador"]
# Out:
# jugador_id
# 8865          Ollie Watkins
# 675           Jack Grealish
# 592            Ross Barkley
# 1024           Tyrone Mings
# 7726       Ezri Konsa Ngoyo
#                ...
# 4267       Florian Hartherz
# 4268    Christian Strohdiek
# 4311             Idir Ouali
# 4334           Mirnes Pepic
# 4363         Thomas Bertels
# Name: nombre_jugador, Length: 18633, dtype: object

# %% [markdown]
# #### Seleccionar 2 o más columnas

# %%
df[["nombre_jugador","año", "juegos"]]
# Out:
#                  nombre_jugador   año  juegos
# jugador_id
# 8865              Ollie Watkins  2020       9
# 675               Jack Grealish  2020       9
# 592                Ross Barkley  2020       6
# 1024               Tyrone Mings  2020       9
# 7726           Ezri Konsa Ngoyo  2020       9
# ...                         ...   ...     ...
# 4267           Florian Hartherz  2014      10
# 4268        Christian Strohdiek  2014      22
# 4311                 Idir Ouali  2014       6
# 4334               Mirnes Pepic  2014       2
# 4363             Thomas Bertels  2014       1
#
# [18633 rows x 3 columns]

# %% [markdown]
# #### Filtrar datos

# %%
df[df.año == 2020]
# Out:
#                 nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 8865             Ollie Watkins  2020       9      6                  5     22
# 675              Jack Grealish  2020       9      5                  5     26
# 592               Ross Barkley  2020       6      2                  2     17
# 1024              Tyrone Mings  2020       9      2                  2      7
# 7726          Ezri Konsa Ngoyo  2020       9      2                  2      7
# ...                        ...   ...     ...    ...                ...    ...
# 8797              Nils Seufert  2020       5      0                  0      1
# 8799            Joakim Nilsson  2020       3      0                  0      1
# 8958             Reinhold Yabo  2020       7      0                  0      3
# 9006            Brian Behrendt  2020       3      0                  0      2
# 9128        Andreas Voglsammer  2020       3      0                  0      1
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 8865                  1                   0               0        F
# 675                   5                   2               0      F M
# 592                   1                   0               0        M
# 1024                  1                   2               0        D
# 7726                  0                   0               0        D
# ...                 ...                 ...             ...      ...
# 8797                  0                   0               0      M S
# 8799                  0                   0               0      D S
# 8958                  0                   0               0      M S
# 9006                  0                   0               0        S
# 9128                  0                   0               0        S
#
#                 nombre_equipo  tiempo
# jugador_id
# 8865              Aston Villa     810
# 675               Aston Villa     810
# 592               Aston Villa     454
# 1024              Aston Villa     810
# 7726              Aston Villa     810
# ...                       ...     ...
# 8797        Arminia Bielefeld     234
# 8799        Arminia Bielefeld     194
# 8958        Arminia Bielefeld     283
# 9006        Arminia Bielefeld      73
# 9128        Arminia Bielefeld      47
#
# [2358 rows x 12 columns]

# %%
df[df['nombre_jugador'] == 'Ollie Watkins']
# Out:
#            nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 8865        Ollie Watkins  2020       9      6                  5     22
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 8865                  1                   0               0        F
#
#            nombre_equipo  tiempo
# jugador_id
# 8865         Aston Villa     810

# %% [markdown]
# También podemos usar **operadores como &** para poner varias condiciones y colocar cada una de ellas entre paréntesis.

# %%
df[(df['año'] == 2020) & (df['nombre_jugador'] == "Jack Grealish")]
# Out:
#            nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 675         Jack Grealish  2020       9      5                  5     26
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 675                   5                   2               0      F M
#
#            nombre_equipo  tiempo
# jugador_id
# 675          Aston Villa     810

# %% [markdown]
# Otra forma de filtrar:

# %%
df.query('nombre_jugador == "Jack Grealish"')
# Out:
#            nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 675         Jack Grealish  2020       9      5                  5     26
# 675         Jack Grealish  2019      36      8                  8     73
# 675         Jack Grealish  2015      16      1                  1     16
# 675         Jack Grealish  2014      17      0                  0     13
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 675                   5                   2               0      F M
# 675                   6                   8               0      F M
# 675                   0                   1               0    F M S
# 675                   1                   0               0    F M S
#
#            nombre_equipo  tiempo
# jugador_id
# 675          Aston Villa     810
# 675          Aston Villa    3235
# 675          Aston Villa     831
# 675          Aston Villa     798

# %% [markdown]
# Se puede añadir una **lista** con varios datos a filtrar.

# %%
anios = [2018, 2019, 2020]

df[df['año'].isin(anios)]
# Out:
#               nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 8865           Ollie Watkins  2020       9      6                  5     22
# 675            Jack Grealish  2020       9      5                  5     26
# 592             Ross Barkley  2020       6      2                  2     17
# 1024            Tyrone Mings  2020       9      2                  2      7
# 7726        Ezri Konsa Ngoyo  2020       9      2                  2      7
# ...                      ...   ...     ...    ...                ...    ...
# 7042         Timothy Tillman  2018       6      0                  0      3
# 7104        Enrico Valentini  2018      15      0                  0      8
# 7105             Kevin Goden  2018       5      0                  0      0
# 7213                 Ewerton  2018      18      0                  0      8
# 7214             Simon Rhein  2018       8      0                  0      1
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 8865                  1                   0               0        F
# 675                   5                   2               0      F M
# 592                   1                   0               0        M
# 1024                  1                   2               0        D
# 7726                  0                   0               0        D
# ...                 ...                 ...             ...      ...
# 7042                  0                   0               0      M S
# 7104                  2                   2               0        D
# 7105                  0                   1               0    D M S
# 7213                  0                   2               0      D S
# 7214                  0                   1               1      M S
#
#            nombre_equipo  tiempo
# jugador_id
# 8865         Aston Villa     810
# 675          Aston Villa     810
# 592          Aston Villa     454
# 1024         Aston Villa     810
# 7726         Aston Villa     810
# ...                  ...     ...
# 7042           Nuernberg     198
# 7104           Nuernberg    1305
# 7105           Nuernberg     270
# 7213           Nuernberg    1339
# 7214           Nuernberg     496
#
# [7746 rows x 12 columns]

# %% [markdown]
# ### Manejo de indices

# %% [markdown]
# #### Colocar una columna como índice

# %%
df.set_index('nombre_jugador')
# Out:
#                       año  juegos  goles  goles_sin_penalti  tiros  \
# nombre_jugador
# Ollie Watkins        2020       9      6                  5     22
# Jack Grealish        2020       9      5                  5     26
# Ross Barkley         2020       6      2                  2     17
# Tyrone Mings         2020       9      2                  2      7
# Ezri Konsa Ngoyo     2020       9      2                  2      7
# ...                   ...     ...    ...                ...    ...
# Florian Hartherz     2014      10      0                  0      1
# Christian Strohdiek  2014      22      0                  0      6
# Idir Ouali           2014       6      0                  0      4
# Mirnes Pepic         2014       2      0                  0      0
# Thomas Bertels       2014       1      0                  0      0
#
#                      asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# nombre_jugador
# Ollie Watkins                  1                   0               0        F
# Jack Grealish                  5                   2               0      F M
# Ross Barkley                   1                   0               0        M
# Tyrone Mings                   1                   2               0        D
# Ezri Konsa Ngoyo               0                   0               0        D
# ...                          ...                 ...             ...      ...
# Florian Hartherz               2                   1               1      D S
# Christian Strohdiek            0                   2               0      D S
# Idir Ouali                     0                   1               0      M S
# Mirnes Pepic                   0                   0               0        S
# Thomas Bertels                 0                   0               0        S
#
#                     nombre_equipo  tiempo
# nombre_jugador
# Ollie Watkins         Aston Villa     810
# Jack Grealish         Aston Villa     810
# Ross Barkley          Aston Villa     454
# Tyrone Mings          Aston Villa     810
# Ezri Konsa Ngoyo      Aston Villa     810
# ...                           ...     ...
# Florian Hartherz        Paderborn     775
# Christian Strohdiek     Paderborn    1608
# Idir Ouali              Paderborn     296
# Mirnes Pepic            Paderborn      20
# Thomas Bertels          Paderborn       3
#
# [18633 rows x 11 columns]

# %% [markdown]
# #### Remover índice

# %%
df.reset_index()
# Out:
#        jugador_id       nombre_jugador   año  juegos  goles  \
# 0            8865        Ollie Watkins  2020       9      6
# 1             675        Jack Grealish  2020       9      5
# 2             592         Ross Barkley  2020       6      2
# 3            1024         Tyrone Mings  2020       9      2
# 4            7726     Ezri Konsa Ngoyo  2020       9      2
# ...           ...                  ...   ...     ...    ...
# 18628        4267     Florian Hartherz  2014      10      0
# 18629        4268  Christian Strohdiek  2014      22      0
# 18630        4311           Idir Ouali  2014       6      0
# 18631        4334         Mirnes Pepic  2014       2      0
# 18632        4363       Thomas Bertels  2014       1      0
#
#        goles_sin_penalti  tiros  asistencias  tarjetas_amarillas  \
# 0                      5     22            1                   0
# 1                      5     26            5                   2
# 2                      2     17            1                   0
# 3                      2      7            1                   2
# 4                      2      7            0                   0
# ...                  ...    ...          ...                 ...
# 18628                  0      1            2                   1
# 18629                  0      6            0                   2
# 18630                  0      4            0                   1
# 18631                  0      0            0                   0
# 18632                  0      0            0                   0
#
#        tarjetas_rojas posicion nombre_equipo  tiempo
# 0                   0        F   Aston Villa     810
# 1                   0      F M   Aston Villa     810
# 2                   0        M   Aston Villa     454
# 3                   0        D   Aston Villa     810
# 4                   0        D   Aston Villa     810
# ...               ...      ...           ...     ...
# 18628               1      D S     Paderborn     775
# 18629               0      D S     Paderborn    1608
# 18630               0      M S     Paderborn     296
# 18631               0        S     Paderborn      20
# 18632               0        S     Paderborn       3
#
# [18633 rows x 13 columns]

# %% [markdown]
# #### Ordenar índice

# %%
df.sort_index(ascending = True)
# Out:
#                 nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 1           Christian Mathenia  2015      33      0                  0      0
# 1           Christian Mathenia  2017      24      0                  0      0
# 1           Christian Mathenia  2018      22      0                  0      0
# 1           Christian Mathenia  2016      14      0                  0      0
# 2                György Garics  2015      21      0                  0      3
# ...                        ...   ...     ...    ...                ...    ...
# 9161          Jan-Luca Schuler  2020       1      0                  0      1
# 9163                Kean Bryan  2020       2      0                  0      0
# 9170                 John Finn  2020       1      0                  0      0
# 9174            Edgar Sevikyan  2020       1      0                  0      0
# 9177          Giuseppe Mastinu  2020       1      0                  0      0
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 1                     0                   3               0       GK
# 1                     0                   2               0       GK
# 1                     0                   2               0       GK
# 1                     0                   1               0       GK
# 2                     0                   8               0      D S
# ...                 ...                 ...             ...      ...
# 9161                  0                   0               0        S
# 9163                  0                   0               0        D
# 9170                  0                   0               0        S
# 9174                  0                   0               0        S
# 9177                  0                   0               0        S
#
#                nombre_equipo  tiempo
# jugador_id
# 1                  Darmstadt    2970
# 1               Hamburger SV    2160
# 1                  Nuernberg    1933
# 1               Hamburger SV    1260
# 2                  Darmstadt    1796
# ...                      ...     ...
# 9161              Schalke 04       8
# 9163        Sheffield United     155
# 9170                  Getafe       4
# 9174                 Levante       5
# 9177                  Spezia       1
#
# [18633 rows x 12 columns]

# %% [markdown]
# #### Seleccionar filas y columnas en una sola línea

# %% [markdown]
# ##### Acceder a todas las filas y **columnas específicas**

# %%
columnas = ["nombre_jugador", "juegos", "goles"]

df.loc[:, columnas]
# Out:
#                  nombre_jugador  juegos  goles
# jugador_id
# 8865              Ollie Watkins       9      6
# 675               Jack Grealish       9      5
# 592                Ross Barkley       6      2
# 1024               Tyrone Mings       9      2
# 7726           Ezri Konsa Ngoyo       9      2
# ...                         ...     ...    ...
# 4267           Florian Hartherz      10      0
# 4268        Christian Strohdiek      22      0
# 4311                 Idir Ouali       6      0
# 4334               Mirnes Pepic       2      0
# 4363             Thomas Bertels       1      0
#
# [18633 rows x 3 columns]

# %% [markdown]
# ##### Acceder a todas las columnas y **filas específicas**

# %%
filas = [675, 4311, 8865]

df.loc[filas]
# Out:
#            nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 675         Jack Grealish  2020       9      5                  5     26
# 675         Jack Grealish  2019      36      8                  8     73
# 675         Jack Grealish  2015      16      1                  1     16
# 675         Jack Grealish  2014      17      0                  0     13
# 4311           Idir Ouali  2014       6      0                  0      4
# 8865        Ollie Watkins  2020       9      6                  5     22
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 675                   5                   2               0      F M
# 675                   6                   8               0      F M
# 675                   0                   1               0    F M S
# 675                   1                   0               0    F M S
# 4311                  0                   1               0      M S
# 8865                  1                   0               0        F
#
#            nombre_equipo  tiempo
# jugador_id
# 675          Aston Villa     810
# 675          Aston Villa    3235
# 675          Aston Villa     831
# 675          Aston Villa     798
# 4311           Paderborn     296
# 8865         Aston Villa     810

# %% [markdown]
# ##### Acceder a **filas y columnas específicas**

# %%
filas = [675, 4311, 8865]
columnas = ["nombre_jugador", "juegos", "goles"]

df.loc[filas, columnas]
# Out:
#            nombre_jugador  juegos  goles
# jugador_id
# 675         Jack Grealish       9      5
# 675         Jack Grealish      36      8
# 675         Jack Grealish      16      1
# 675         Jack Grealish      17      0
# 4311           Idir Ouali       6      0
# 8865        Ollie Watkins       9      6

# %% [markdown]
# Si se tienen los índices ordenados, se puede usar **slicing[ : : ]**.

# %%
df_ordenado = df.sort_index(ascending = True)

df_ordenado
# Out:
#                 nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 1           Christian Mathenia  2015      33      0                  0      0
# 1           Christian Mathenia  2017      24      0                  0      0
# 1           Christian Mathenia  2018      22      0                  0      0
# 1           Christian Mathenia  2016      14      0                  0      0
# 2                György Garics  2015      21      0                  0      3
# ...                        ...   ...     ...    ...                ...    ...
# 9161          Jan-Luca Schuler  2020       1      0                  0      1
# 9163                Kean Bryan  2020       2      0                  0      0
# 9170                 John Finn  2020       1      0                  0      0
# 9174            Edgar Sevikyan  2020       1      0                  0      0
# 9177          Giuseppe Mastinu  2020       1      0                  0      0
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 1                     0                   3               0       GK
# 1                     0                   2               0       GK
# 1                     0                   2               0       GK
# 1                     0                   1               0       GK
# 2                     0                   8               0      D S
# ...                 ...                 ...             ...      ...
# 9161                  0                   0               0        S
# 9163                  0                   0               0        D
# 9170                  0                   0               0        S
# 9174                  0                   0               0        S
# 9177                  0                   0               0        S
#
#                nombre_equipo  tiempo
# jugador_id
# 1                  Darmstadt    2970
# 1               Hamburger SV    2160
# 1                  Nuernberg    1933
# 1               Hamburger SV    1260
# 2                  Darmstadt    1796
# ...                      ...     ...
# 9161              Schalke 04       8
# 9163        Sheffield United     155
# 9170                  Getafe       4
# 9174                 Levante       5
# 9177                  Spezia       1
#
# [18633 rows x 12 columns]

# %%
df_ordenado[5:11]
# Out:
#             nombre_jugador   año  juegos  goles  goles_sin_penalti  tiros  \
# jugador_id
# 3           Luca Caldirola  2014       7      1                  1      1
# 3           Luca Caldirola  2015      34      0                  0     15
# 3           Luca Caldirola  2020       9      2                  2      4
# 3           Luca Caldirola  2017       1      0                  0      0
# 3           Luca Caldirola  2016       5      0                  0      2
# 4               Aytac Sulu  2015      33      7                  7     21
#
#             asistencias  tarjetas_amarillas  tarjetas_rojas posicion  \
# jugador_id
# 3                     0                   2               1      D S
# 3                     1                   4               0        D
# 3                     0                   2               0        D
# 3                     0                   0               0        D
# 3                     0                   1               0        D
# 4                     0                   6               0        D
#
#             nombre_equipo  tiempo
# jugador_id
# 3           Werder Bremen     470
# 3               Darmstadt    3060
# 3               Benevento     708
# 3           Werder Bremen      90
# 3           Werder Bremen     413
# 4               Darmstadt    2970

# %% [markdown]
# ### Aplicacion de funciones a un DataFrame

# %% [markdown]
# Como Pandas está escrito sobre **NumPy**, podemos usar muchas de las funciones de NumPy en las columnas del DataFrame, junto con otras nativas de Pandas.

# %% [markdown]
# #### Sumar todos los valores de una columna

# %%
goles_totales = df["goles"].sum()

goles_totales
# Out:
# 30261

# %% [markdown]
# #### Promedio de todos los valores de una columna

# %%
goles_promedio = df["goles"].mean()

goles_promedio
# Out:
# 1.6240540975688296

# %% [markdown]
# #### Valor maximo de una columna

# %%
goles_max = df["goles"].max()

goles_max
# Out:
# 48

# %% [markdown]
# #### Valor minimo de una columna

# %%
goles_min = df["goles"].min()

goles_min
# Out:
# 0

# %% [markdown]
# #### Suma acumulada de una columna

# %%
goles_acumulados = df["goles"].cumsum()

goles_acumulados
# Out:
# jugador_id
# 8865        6
# 675        11
# 592        13
# 1024       15
# 7726       17
#         ...
# 4267    30261
# 4268    30261
# 4311    30261
# 4334    30261
# 4363    30261
# Name: goles, Length: 18633, dtype: int64

# %% [markdown]
# #### Valor maximo acumulado de una columna

# %%
goles_maximo_acumulado = df["goles"].cummax()

goles_maximo_acumulado
# Out:
# jugador_id
# 8865     6
# 675      6
# 592      6
# 1024     6
# 7726     6
#         ..
# 4267    48
# 4268    48
# 4311    48
# 4334    48
# 4363    48
# Name: goles, Length: 18633, dtype: int64

# %% [markdown]
# #### Contar distintos valores de una columna

# %% [markdown]
# Resulta muy útil para contar categorías. Se debe tener en cuenta que se ordena de manera **descendente**.

# %%
equipos = df["nombre_equipo"].value_counts(sort = True)

equipos
# Out:
# nombre_equipo
# Genoa                222
# Monaco               217
# Saint-Etienne        212
# Nice                 209
# Atalanta             205
#                     ...
# Nancy                 27
# Cardiff               25
# Arminia Bielefeld     23
# GFC Ajaccio           23
# Leeds                 20
# Name: count, Length: 147, dtype: int64

# %% [markdown]
# #### Eliminar duplicados de una columna

# %%
jugadores = df.drop_duplicates(subset='nombre_jugador')

jugadores["nombre_jugador"]
# Out:
# jugador_id
# 8865       Ollie Watkins
# 675        Jack Grealish
# 592         Ross Barkley
# 1024        Tyrone Mings
# 7726    Ezri Konsa Ngoyo
#               ...
# 4260     Patrick Ziegler
# 4267    Florian Hartherz
# 4311          Idir Ouali
# 4334        Mirnes Pepic
# 4363      Thomas Bertels
# Name: nombre_jugador, Length: 6171, dtype: object

# %% [markdown]
# #### Funciones agregadas

# %%
df_materias = pd.DataFrame([[100, 95, 87],[94, 92, 81],[75,84,91]],columns=['Matematicas', 'Ingles','Ciencias'])

df_materias
# Out:
#    Matematicas  Ingles  Ciencias
# 0          100      95        87
# 1           94      92        81
# 2           75      84        91

# %% [markdown]
# Intentemos calcular la puntuación total obtenida por cada estudiante en todas las materias.... podemos notar que necesitamos realizar una función agregada de la suma sobre todas las filas.

# %%
df_materias.agg(['sum'], 1) # Filas
# Out:
#    sum
# 0  282
# 1  267
# 2  250

# %% [markdown]
# Podemos intentar obtener las calificaciones promedio de los estudiantes en todas las materias.

# %%
df_materias.agg(['sum'], 0) # Columnas
# Out:
#      Matematicas  Ingles  Ciencias
# sum          269     271       259

# %% [markdown]
# Podemos realizar varias operaciones con las funciones agregadas.

# %%
df_materias.agg(['average','min','max'], 0) # Columnas
# Out:
#          Matematicas     Ingles   Ciencias
# average    89.666667  90.333333  86.333333
# min        75.000000  84.000000  81.000000
# max       100.000000  95.000000  91.000000

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Indique el jugador con la mayor cantidad de goles realizados en una temporada

# %%
# Puede realizar su codigo en esta celda

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Calcule el porcentaje de tiros al arco que terminan en gol, tenga en cuenta lo siguiente:

# %% [markdown]
# $porcentaje = goles totales / tiros totales * 100$

# %%
# Puede realizar su codigo en esta celda

# %% [markdown]
# ### Agrupacion de datos

# %% [markdown]
# En este **dataset**, cada fila representa los datos de un año entero para cada jugador.
#
# Sin embargo, seria mucho más interesante ver las estadísticas de todos los años al mismo tiempo para todos los jugadores, lo cual podemos lograr con la agrupacion utilizando **.groupby()**.

# %% [markdown]
# #### Agrupacion y media

# %% [markdown]
# **Agrupa los datos** de la columna que está entre **paréntesis ()** y obtiene la **media** de la columna que está entre **corchetes []**

# %%
agrupacion_nombre_media_goles = df.groupby('nombre_jugador')['goles'].mean()

agrupacion_nombre_media_goles
# Out:
# nombre_jugador
# Aaron Connolly      4
# Aaron Cresswell     8
# Aaron Hickey        0
# Aaron Hunt         10
# Aaron Lennon        8
#                    ..
# Óscar Romero        0
# Óscar Trejo        11
# Ömer Toprak         3
# Özkan Yildirim      0
# Ørjan Nyland        0
# Name: goles, Length: 6171, dtype: int64

# %% [markdown]
# #### Agrupacion y suma

# %% [markdown]
# **Agrupa los datos** de la columna que está entre **paréntesis ()** y obtiene la **suma** de la columna que está entre **corchetes []**

# %%
agrupacion_nombre_suma_goles = df.groupby('nombre_jugador')['goles'].sum()

agrupacion_nombre_suma_goles
# Out:
# nombre_jugador
# Aaron Connolly      4
# Aaron Cresswell     8
# Aaron Hickey        0
# Aaron Hunt         10
# Aaron Lennon        8
#                    ..
# Óscar Romero        0
# Óscar Trejo        11
# Ömer Toprak         3
# Özkan Yildirim      0
# Ørjan Nyland        0
# Name: goles, Length: 6171, dtype: int64

# %% [markdown]
# #### Agrupacion y estadísticas múltiples

# %%
agrupacion_nombre_estadisticas = df.groupby('nombre_jugador')['goles'].agg([min, max, sum])

agrupacion_nombre_estadisticas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 agrupacion_nombre_estadisticas = df.groupby('nombre_jugador')['goles'].agg([min, max, sum])
#       3 agrupacion_nombre_estadisticas
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Agrupacion de varias columnas

# %%
agrupacion = df.groupby(['jugador_id', 'nombre_jugador'])['goles'].mean()

agrupacion
# Out:
# jugador_id  nombre_jugador
# 1           Christian Mathenia    0.0
# 2           György Garics         0.0
# 3           Luca Caldirola        0.6
# 4           Aytac Sulu            4.5
# 5           Fabian Holland        0.0
#                                  ...
# 9161        Jan-Luca Schuler      0.0
# 9163        Kean Bryan            0.0
# 9170        John Finn             0.0
# 9174        Edgar Sevikyan        0.0
# 9177        Giuseppe Mastinu      0.0
# Name: goles, Length: 6242, dtype: float64

# %% [markdown]
# #### Agrupacion y media de varias columnas

# %%
agrupacion = df.groupby(['jugador_id', 'nombre_jugador'])[['goles','tiros']].mean()

agrupacion
# Out:
#                                goles  tiros
# jugador_id nombre_jugador
# 1          Christian Mathenia    0.0    0.0
# 2          György Garics         0.0    3.0
# 3          Luca Caldirola        0.6    4.4
# 4          Aytac Sulu            4.5   23.0
# 5          Fabian Holland        0.0    2.5
# ...                              ...    ...
# 9161       Jan-Luca Schuler      0.0    1.0
# 9163       Kean Bryan            0.0    0.0
# 9170       John Finn             0.0    0.0
# 9174       Edgar Sevikyan        0.0    0.0
# 9177       Giuseppe Mastinu      0.0    0.0
#
# [6242 rows x 2 columns]

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# Calcule los 10 jugadores que más goles han marcado.

# %%
# Puede resolver el ejercicio en esta celda

# %% [markdown]
# ### Ejercicio 4

# %% [markdown]
# Calcule el top 5 de equipos con más tarjetas rojas y amarillas.

# %%
# Puede resolver el ejercicio en esta celda

# %% [markdown]
# ### Creacion de columnas

# %% [markdown]
# Se puede crear una columna de la siguiente manera:
#
# ```python
# df['nombre_columna'] = valores.
# ```
#
# Es parecido a crear un nuevo par **llave:valor en un diccionario**, y operar en columnas es muy parecido a operar con **arreglos de NumPy**.

# %%
df['tarjetas_totales'] = df['tarjetas_rojas'] + df['tarjetas_amarillas']

agrupacion_nombre_suma_tarjetas = df.groupby(['nombre_jugador'])['tarjetas_totales'].sum()

agrupacion_nombre_suma_tarjetas
# Out:
# nombre_jugador
# Aaron Connolly      0
# Aaron Cresswell    24
# Aaron Hickey        3
# Aaron Hunt          7
# Aaron Lennon       11
#                    ..
# Óscar Romero        3
# Óscar Trejo        21
# Ömer Toprak        21
# Özkan Yildirim      0
# Ørjan Nyland        0
# Name: tarjetas_totales, Length: 6171, dtype: int64

# %%
df['tarjetas_totales'] = df['tarjetas_rojas'] + df['tarjetas_amarillas']

agrupacion_nombre_suma_tarjetas = df.groupby('nombre_jugador').agg(
    tarjetas_amarillas = ('tarjetas_amarillas', 'sum'),
    tarjetas_rojas = ('tarjetas_rojas', 'sum'),
    tarjetas_totales = ('tarjetas_totales', 'sum')
)

agrupacion_nombre_suma_tarjetas
# Out:
#                  tarjetas_amarillas  tarjetas_rojas  tarjetas_totales
# nombre_jugador
# Aaron Connolly                    0               0                 0
# Aaron Cresswell                  23               1                24
# Aaron Hickey                      3               0                 3
# Aaron Hunt                        7               0                 7
# Aaron Lennon                     11               0                11
# ...                             ...             ...               ...
# Óscar Romero                      3               0                 3
# Óscar Trejo                      19               2                21
# Ömer Toprak                      21               0                21
# Özkan Yildirim                    0               0                 0
# Ørjan Nyland                      0               0                 0
#
# [6171 rows x 3 columns]

# %% [markdown]
# ### Ejercicio 5

# %% [markdown]
# Indique quienes fueron los 5 jugadores más efectivos, para ello debe sumar el total de goles y asistencias de un solo jugador y guardarlo en una nueva columna.

# %%
# En esta celda puede resolver el ejercicio

# %% [markdown]
# ### Exportar datos de Pandas

# %% [markdown]
# Pandas trae una serie de funciones que te permiten exportar tus datos al formato que quieras.
#
# Su estructura es:
#
# ```python
# df.to_{tipo_de_archivo}('ruta/nombre_archivo')
# ```
#
# Además, en caso de tener la lista de índices por defecto, podriamos no exportarla usando **index = False**.

# %%
df.to_csv('futbol_analisis.csv', index = False)

# %% [markdown]
# ### Ejercicio 6

# %% [markdown]
# Encuentra la cantidad de goles totales hechos por cada posición.

# %% [markdown]
# - D: Defensor (Defender).
# - DF: Defensor (Defender).
# - DFM: Defensor Medio (Defensive Midfielder).
# - DFMS: Defensor Medio Ofensivo (Defensive Midfielder / Striker).
# - DFS: Defensor Medio Ofensivo (Defensive Midfielder / Striker).
# - DM: Centrocampista Defensivo (Defensive Midfielder).
# - DMS: Defensor Medio Ofensivo (Defensive Midfielder / Striker).
# - DS: Delantero (Striker).
# - F: Delantero (Forward).
# - FM: Delantero Medio (Forward Midfielder).
# - FMS: Delantero Medio Ofensivo (Forward Midfielder / Striker).
# - FS: Delantero Medio Ofensivo (Forward Midfielder / Striker).
# - GK: Portero (Goalkeeper).
# - GK S: Portero Suplente (Substitute Goalkeeper).
# - M: Centrocampista (Midfielder).
# - MS: Medio Ofensivo (Midfielder / Striker).
# - S: Delantero (Striker).

# %%
# En esta celda puede resolver el ejercicio

# %% [markdown]
# ### Ejercicio 7

# %% [markdown]
# ¿Cuál es el jugador que más tiempo ha jugado y cuál es la media de tiempo de todos los jugadores?
#
# Esta pregunta tiene truco porque hay muchos jugadores suplentes que no juegan casi nunca y van a sesgar los datos, ¿cómo se podría solucionar esto?

# %%
# En esta celda puede resolver el ejercicio

# %% [markdown]
# ### Ejercicio 8

# %% [markdown]
# Calcule cual es el porcentaje de goles hechos por penales. Utilice la columna goles_sin_penalti.

# %%
# En esta celda puede resolver el ejercicio

# %% [markdown]
# ### Ejercicio 9

# %% [markdown]
# ¿Qué porcentaje de goles son hechos con asistencias?

# %%
# En esta celda puede resolver el ejercicio
